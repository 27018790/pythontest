# %%
#import pandas_datareader.data as pdr
import pandas_datareader.data as web

import os
import pandas as pd
symbol = 'WIKI/AAPL'  # or 'AAPL.US'
QUANDL_API_KEY = "HyDdMTXQR1r8mhw5QyXh"  
av_apikey='J4L80CM3ATCKNONG'
#df = web.DataReader(symbol, 'quandl', '2015-01-01', '2015-01-05')
#df = pdr.get_data_tiingo('GOOG', api_key=os.getenv('TIINGO_API_KEY'))

#df.head()
#import pandas_datareader.data as web
#start = datetime.datetime(2016, 1, 1) # 
start = '1/1/2010'
end = '1/1/2020'
prices = web.DataReader('AAPL', 'quandl', start, end,api_key=QUANDL_API_KEY)
prices.head()  # print first rows of the prices data
# Out:
#               Open    High     Low    Close      Volume  ExDividend  \
# Date
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0         0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0         0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0         0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0         0.0
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# Date
# 2018-03-27         1.0   173.68   175.15  166.92   168.340  38962839.0
# 2018-03-26         1.0   168.07   173.10  166.44   172.770  36272617.0
# 2018-03-23         1.0   168.39   169.92  164.94   164.940  40248954.0
# 2018-03-22         1.0   170.00   172.68  168.60   168.845  41051076.0
# 2018-03-21         1.0   175.04   175.09  171.26   171.270  35247358.0

# %%
#import pandas_datareader.data as pdr
import pandas_datareader.data as web
from datetime import datetime
import os
import pandas as pd
av_apikey='J4L80CM3ATCKNONG'
f = web.DataReader("AAPL", "av-daily", start=datetime(2017, 2, 9),end=datetime(2017, 5, 24),api_key=av_apikey)
f
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# d:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     330             try:
# --> 331                 yield
#     332
#
# d:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     639                     break
# --> 640                 chunk = self._handle_chunk(amt)
#     641                 decoded = self._decode(chunk, decode_content=decode_content,
#
# d:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in _handle_chunk(self, amt)
#     585         elif amt < self.chunk_left:
# --> 586             value = self._fp._safe_read(amt)
#     587             self.chunk_left = self.chunk_left - amt
#
# d:\ProgramData\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     611             if not chunk:
# ...

# %%
import requests
import pandas as pd
import io

apikey = 'J4L80CM3ATCKNONG'

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=full&symbol=MSFT&apikey=' + apikey + '&datatype=csv'
urlweek = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&outputsize=full&symbol=MSFT&apikey=' + apikey + '&datatype=csv'
urlweekad = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&outputsize=full&symbol=MSFT&apikey=' + apikey + '&datatype=csv'

s = requests.get(urlweekad).content

stock = pd.read_csv(io.StringIO(s.decode('utf-8')))

print(stock)
# Out:
#        timestamp      open      high       low   close  adjusted close  \
# 0     2020-01-29  161.1500  168.7500  160.2000  168.04        168.0400
# 1     2020-01-24  166.6800  168.1900  164.4500  165.04        165.0400
# 2     2020-01-17  161.7600  167.4675  161.2600  167.10        167.1000
# 3     2020-01-10  157.0800  163.2200  156.5100  161.34        161.3400
# 4     2020-01-03  158.9865  160.7300  156.4500  158.62        158.6200
# 5     2019-12-27  158.1200  159.5500  157.1150  158.96        158.9600
# 6     2019-12-20  155.1100  158.4900  153.7500  157.41        157.4100
# 7     2019-12-13  151.0700  154.8900  150.3300  154.53        154.5300
# 8     2019-12-06  151.8100  151.8700  146.6500  151.75        151.7500
# 9     2019-11-29  150.0000  152.5000  149.9200  151.38        151.3800
# 10    2019-11-22  150.0700  151.3300  148.4600  149.59        149.5900
# 11    2019-11-15  145.3400  149.9900  144.7300  149.97        149.4605
# ...
